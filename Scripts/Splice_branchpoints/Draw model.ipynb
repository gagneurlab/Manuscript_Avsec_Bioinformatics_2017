# %%
import data
import model
from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
# Out:
# Using TensorFlow backend.

# %%
train, test = data.data()

# %%
m = model.model(train, )
# Out:
# Removing 1 pwm's from pwm_list
# Removing 1 pwm's from pwm_list

# %%
SVG(model_to_dot(m).create(prog='dot', format='svg'))

# %%
plot_model(m, to_file='../../../data/plots/Concise/Paper/shallow_model_example.png',show_shapes=False)

# %%
ls ../../../
# Out:
# 2016-06-06-Ziga-retreat-deepCis.png  make.config       Scripts/
# bin/                                 Makefile          slurm-log/
# data@                                meeting-notes/    Snakefile
# data-offline/                        nbs/              Snakefile~
# deepcis.org                          posters/          src/
# documents/                           readme.md         Todo.md
# localdata/                           requirements.txt
